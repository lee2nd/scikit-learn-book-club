# %% [markdown]
# # GridSearchCV
#
# 下面來舉一個簡單的使用範例

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

X, y = datasets.load_digits(return_X_y=True)
n_samples = len(X)
X = X.reshape((n_samples, -1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=87)

# 設置搜尋參數
tuned_parameters = [
    {'kernel': ['rbf'], 
     'gamma': [1e-3, 1e-4, 'scale'],
     'C': [1, 10, 100, 1000],
     },
    {'kernel': ['linear'], 
     'C': [1, 10, 100, 1000],
     },
    {'kernel': ['poly'],
     'gamma': ['scale', 'auto'],
     'degree': [2, 3, 4, 5, 6],
     'C': [1, 10, 100, 1000],
     },
]

scores = ['precision_macro', 'recall_micro', 'f1_weighted', 
          'accuracy', 'balanced_accuracy']

for score in scores:
    print("# Tuning hyper-parameters for %s \n" % score)

    classifier = GridSearchCV(
        SVC(), tuned_parameters, scoring='%s' % score
    ).fit(X_train, y_train)

    print("Best parameters set found on development set: \n")
    print(classifier.best_params_)
    print("\nGrid scores on development set:\n")
    
    means = classifier.cv_results_['mean_test_score']
    stds = classifier.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, classifier.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    
    print("\nDetailed classification report:\n")
    y_pred = classifier.predict(X_test)
    print(classification_report(y_test, y_pred))
# Out:
# # Tuning hyper-parameters for precision_macro
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.988 (+/-0.008) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.967 (+/-0.007) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.988 (+/-0.010) for {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.990 (+/-0.014) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.983 (+/-0.017) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.011) for {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.990 (+/-0.014) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.984 (+/-0.016) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.011) for {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.990 (+/-0.014) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.984 (+/-0.016) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.011) for {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.972 (+/-0.017) for {'C': 1, 'kernel': 'linear'}
# 0.972 (+/-0.017) for {'C': 10, 'kernel': 'linear'}
# 0.972 (+/-0.017) for {'C': 100, 'kernel': 'linear'}
# 0.972 (+/-0.017) for {'C': 1000, 'kernel': 'linear'}
# 0.983 (+/-0.013) for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.018) for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.012) for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.013) for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.011) for {'C': 1, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.011) for {'C': 1, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.976 (+/-0.020) for {'C': 1, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.975 (+/-0.017) for {'C': 1, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.018) for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.018) for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.013) for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.013) for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.011) for {'C': 10, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.011) for {'C': 10, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.975 (+/-0.017) for {'C': 10, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.975 (+/-0.017) for {'C': 10, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.018) for {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.018) for {'C': 100, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.013) for {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.013) for {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.011) for {'C': 100, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.011) for {'C': 100, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.975 (+/-0.017) for {'C': 100, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.975 (+/-0.017) for {'C': 100, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.018) for {'C': 1000, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.018) for {'C': 1000, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.013) for {'C': 1000, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.013) for {'C': 1000, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.011) for {'C': 1000, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.985 (+/-0.011) for {'C': 1000, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 1000, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 1000, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.975 (+/-0.017) for {'C': 1000, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.975 (+/-0.017) for {'C': 1000, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       0.96      1.00      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.97      0.98        86
#            4       1.00      1.00      1.00        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.98      0.98        89
#            8       0.99      0.94      0.96        77
#            9       0.98      0.98      0.98        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
#
# # Tuning hyper-parameters for recall_micro
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.987 (+/-0.009) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.963 (+/-0.005) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.987 (+/-0.011) for {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.981 (+/-0.019) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.019) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.019) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.970 (+/-0.019) for {'C': 1, 'kernel': 'linear'}
# 0.970 (+/-0.019) for {'C': 10, 'kernel': 'linear'}
# 0.970 (+/-0.019) for {'C': 100, 'kernel': 'linear'}
# 0.970 (+/-0.019) for {'C': 1000, 'kernel': 'linear'}
# 0.981 (+/-0.015) for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.982 (+/-0.013) for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.974 (+/-0.022) for {'C': 1, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 10, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 10, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 10, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 10, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 100, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 100, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 100, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 100, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 100, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1000, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1000, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1000, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1000, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1000, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1000, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1000, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1000, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1000, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1000, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       0.96      1.00      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.97      0.98        86
#            4       1.00      1.00      1.00        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.98      0.98        89
#            8       0.99      0.94      0.96        77
#            9       0.98      0.98      0.98        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
#
# # Tuning hyper-parameters for f1_weighted
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.987 (+/-0.009) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.963 (+/-0.006) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.987 (+/-0.011) for {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.981 (+/-0.020) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.020) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.020) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.970 (+/-0.020) for {'C': 1, 'kernel': 'linear'}
# 0.970 (+/-0.020) for {'C': 10, 'kernel': 'linear'}
# 0.970 (+/-0.020) for {'C': 100, 'kernel': 'linear'}
# 0.970 (+/-0.020) for {'C': 1000, 'kernel': 'linear'}
# 0.981 (+/-0.016) for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.982 (+/-0.013) for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.974 (+/-0.022) for {'C': 1, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 10, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 10, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 10, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 10, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 100, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 100, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 100, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 100, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 100, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1000, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1000, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1000, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1000, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1000, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1000, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1000, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1000, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1000, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1000, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       0.96      1.00      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.97      0.98        86
#            4       1.00      1.00      1.00        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.98      0.98        89
#            8       0.99      0.94      0.96        77
#            9       0.98      0.98      0.98        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
#
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.987 (+/-0.009) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.963 (+/-0.005) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.987 (+/-0.011) for {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.981 (+/-0.019) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.019) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.019) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.970 (+/-0.019) for {'C': 1, 'kernel': 'linear'}
# 0.970 (+/-0.019) for {'C': 10, 'kernel': 'linear'}
# 0.970 (+/-0.019) for {'C': 100, 'kernel': 'linear'}
# 0.970 (+/-0.019) for {'C': 1000, 'kernel': 'linear'}
# 0.981 (+/-0.015) for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.982 (+/-0.013) for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.974 (+/-0.022) for {'C': 1, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 10, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 10, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 10, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 10, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 100, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 100, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 100, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 100, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 100, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1000, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 1000, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1000, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.016) for {'C': 1000, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1000, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.983 (+/-0.012) for {'C': 1000, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1000, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.978 (+/-0.017) for {'C': 1000, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1000, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.973 (+/-0.018) for {'C': 1000, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       0.96      1.00      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.97      0.98        86
#            4       1.00      1.00      1.00        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.98      0.98        89
#            8       0.99      0.94      0.96        77
#            9       0.98      0.98      0.98        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
#
# # Tuning hyper-parameters for balanced_accuracy
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.987 (+/-0.009) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.964 (+/-0.005) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.987 (+/-0.011) for {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.018) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.011) for {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.983 (+/-0.017) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.011) for {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.983 (+/-0.017) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.011) for {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.971 (+/-0.017) for {'C': 1, 'kernel': 'linear'}
# 0.971 (+/-0.017) for {'C': 10, 'kernel': 'linear'}
# 0.971 (+/-0.017) for {'C': 100, 'kernel': 'linear'}
# 0.971 (+/-0.017) for {'C': 1000, 'kernel': 'linear'}
# 0.982 (+/-0.014) for {'C': 1, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.019) for {'C': 1, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.013) for {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.015) for {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.011) for {'C': 1, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.011) for {'C': 1, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.975 (+/-0.021) for {'C': 1, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.974 (+/-0.017) for {'C': 1, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.019) for {'C': 10, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.019) for {'C': 10, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.015) for {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.015) for {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.011) for {'C': 10, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.011) for {'C': 10, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.974 (+/-0.017) for {'C': 10, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.974 (+/-0.017) for {'C': 10, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.019) for {'C': 100, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.019) for {'C': 100, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.015) for {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.015) for {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.011) for {'C': 100, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.011) for {'C': 100, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.974 (+/-0.017) for {'C': 100, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.974 (+/-0.017) for {'C': 100, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.019) for {'C': 1000, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.019) for {'C': 1000, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.015) for {'C': 1000, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.015) for {'C': 1000, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.984 (+/-0.011) for {'C': 1000, 'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.011) for {'C': 1000, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 1000, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 1000, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.974 (+/-0.017) for {'C': 1000, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.974 (+/-0.017) for {'C': 1000, 'degree': 6, 'gamma': 'auto', 'kernel': 'poly'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       0.96      1.00      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.97      0.98        86
#            4       1.00      1.00      1.00        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.98      0.98        89
#            8       0.99      0.94      0.96        77
#            9       0.98      0.98      0.98        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899

# %% [markdown]
# ## 可以查詢有哪些是可以使用的 scorer

# %%
from sklearn import metrics

metrics.get_scorer_names()
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'matthews_corrcoef',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_absolute_percentage_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'top_k_accuracy',
#  'v_measure_score']

# %% [markdown]
# # XGboost with GridSearchCV
#
# * n_estimators：樹的數量
# * eta [defalt = 0.3, 別名 : leanring_rate]： 學習步長
# * max_depth [defalt = 6]：樹的最大深度，越大越容易 overfitting
# * min_child_weight [defalt = 1]：最小葉子節點的權重合。當他的值大可以避免學到局部樣本。如果太大會發生 overfitting
# * lambda [defalt = 1, 別名 : reg_alpha]： L2 正則化權重，越大必免 overfitting
# * alpha [defalt = 0, 別名 : reg_alpha]： L1 正則化權重，越大必免 overfitting
# * seed：隨機樹種子
#
# 更多參數請[參考官網](https://xgboost.readthedocs.io/en/latest/parameter.html#general-parameters)
#
# 下面給一個 XGboost + Pipeline + GridSearchCV 的使用範例，
# 有其他需求可以拿他來改。

# %%
from xgboost import XGBClassifier
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X, y = datasets.load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=87)

# 設置搜尋參數
tuned_parameters = [
    {'classifier__n_estimators': [100, 200, 300], 
     'classifier__max_depth': [1, 2, 3],
     'classifier__min_child_weight': [1, 2, 3],
     },
]

# 設置 Pipeline
estimators = [
    ('reduce_dim', PCA()), 
    ('scaler', StandardScaler()),
    ('classifier', XGBClassifier())
]
pipeline = Pipeline(estimators)

scores = ['accuracy']

for score in scores:
    print("# Tuning hyper-parameters for %s \n" % score)

    classifier = GridSearchCV(
        pipeline, 
        tuned_parameters, 
        scoring='%s' % score,
        cv=3
    ).fit(X_train, y_train)

    print("Best parameters set found on development set: \n")
    print(classifier.best_params_)
    print("\nGrid scores on development set:\n")
    
    means = classifier.cv_results_['mean_test_score']
    stds = classifier.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, classifier.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    
    print("\nDetailed classification report:\n")
    y_pred = classifier.predict(X_test)
    print(classification_report(y_test, y_pred))
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'classifier__max_depth': 1, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 100}
#
# Grid scores on development set:
#
# 0.958 (+/-0.062) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 100}
# 0.958 (+/-0.062) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 200}
# 0.958 (+/-0.062) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 300}
# 0.950 (+/-0.071) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 100}
# 0.950 (+/-0.071) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 200}
# 0.942 (+/-0.047) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 300}
# 0.942 (+/-0.047) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 100}
# 0.942 (+/-0.047) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 200}
# 0.933 (+/-0.062) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 300}
# 0.958 (+/-0.062) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 100}
# 0.958 (+/-0.062) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 200}
# 0.958 (+/-0.062) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 300}
# 0.958 (+/-0.062) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 100}
# 0.950 (+/-0.041) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 200}
# 0.950 (+/-0.041) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 300}
# 0.950 (+/-0.041) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 100}
# 0.950 (+/-0.041) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 200}
# 0.950 (+/-0.041) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 300}
# 0.958 (+/-0.062) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 100}
# 0.958 (+/-0.062) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 200}
# 0.958 (+/-0.062) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 300}
# 0.958 (+/-0.062) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 100}
# 0.958 (+/-0.062) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 200}
# 0.958 (+/-0.062) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 300}
# 0.950 (+/-0.041) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 100}
# 0.933 (+/-0.062) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 200}
# 0.933 (+/-0.062) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 300}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.89      0.94         9
#            2       0.89      1.00      0.94         8
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # LightGBM with GridSearchCV
#
# 更多參數請[參考官網](https://lightgbm.readthedocs.io/en/v3.3.2/Parameters.html)
#
# 下面也是給個使用範例

# %%
import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X, y = datasets.load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=87)

# 設置搜尋參數
tuned_parameters = [
    {'classifier__n_estimators': [100, 200, 300], 
     'classifier__max_depth': [1, 2, 3],
     'classifier__min_child_weight': [1, 2, 3],
     },
]

# 設置 Pipeline
estimators = [
    ('reduce_dim', PCA()), 
    ('scaler', StandardScaler()),
    ('classifier', LGBMClassifier())
]
pipeline = Pipeline(estimators)


scores = ['accuracy']

for score in scores:
    print("# Tuning hyper-parameters for %s \n" % score)

    classifier = GridSearchCV(
        pipeline, 
        tuned_parameters, 
        scoring='%s' % score,
        cv=3
    ).fit(X_train, y_train)

    print("Best parameters set found on development set: \n")
    print(classifier.best_params_)
    print("\nGrid scores on development set:\n")
    
    means = classifier.cv_results_['mean_test_score']
    stds = classifier.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, classifier.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    
    print("\nDetailed classification report:\n")
    y_pred = classifier.predict(X_test)
    print(classification_report(y_test, y_pred))
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'classifier__max_depth': 1, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 100}
#
# Grid scores on development set:
#
# 0.950 (+/-0.041) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 100}
# 0.950 (+/-0.041) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 200}
# 0.950 (+/-0.041) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 300}
# 0.950 (+/-0.041) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 100}
# 0.950 (+/-0.041) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 200}
# 0.950 (+/-0.041) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 300}
# 0.942 (+/-0.047) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 100}
# 0.933 (+/-0.062) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 200}
# 0.933 (+/-0.062) for {'classifier__max_depth': 1, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 300}
# 0.950 (+/-0.041) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 100}
# 0.942 (+/-0.047) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 200}
# 0.942 (+/-0.047) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 300}
# 0.942 (+/-0.047) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 100}
# 0.942 (+/-0.047) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 200}
# 0.942 (+/-0.047) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 300}
# 0.942 (+/-0.047) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 100}
# 0.942 (+/-0.047) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 200}
# 0.942 (+/-0.047) for {'classifier__max_depth': 2, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 300}
# 0.950 (+/-0.041) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 100}
# 0.950 (+/-0.041) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 200}
# 0.942 (+/-0.047) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 1, 'classifier__n_estimators': 300}
# 0.942 (+/-0.047) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 100}
# 0.942 (+/-0.047) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 200}
# 0.942 (+/-0.047) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 2, 'classifier__n_estimators': 300}
# 0.942 (+/-0.047) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 100}
# 0.942 (+/-0.047) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 200}
# 0.942 (+/-0.047) for {'classifier__max_depth': 3, 'classifier__min_child_weight': 3, 'classifier__n_estimators': 300}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        13
#            1       0.89      0.89      0.89         9
#            2       0.89      1.00      0.94         8
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.94      0.93        30
# weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# # RandomizedSearchCV
#
# 在很多時候我們並不知道那些參數好，使用 RandomizedSearchCV，
# 可以讓收尋空間是某個 distribution 。
#
# 下面是一個使用範例

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC
import numpy as np
from scipy.stats import uniform
from sklearn.utils.fixes import loguniform

X, y = datasets.load_digits(return_X_y=True)
n_samples = len(X)
X = X.reshape((n_samples, -1))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=87)

# 設置搜尋參數
tuned_parameters = [
    {'kernel': ['rbf'], 
     'gamma': [1e-3, 1e-4, 'scale'],
     'C': uniform(loc=1, scale=999),                  # 均勻分布 
     },
    {'kernel': ['linear'], 
     'C': np.logspace(0, 3, base=10, num = 100),      # log 均勻分布  base^0  ~ base^3
     },
    {'kernel': ['poly'],
     'gamma': ['scale', 'auto'],
     'degree': [2, 3, 4, 5, 6],
     'C': loguniform(1e0, 1e3),                        # 也是 log 均勻分布
     },
]

scores = ['precision_macro', 'recall_micro', 'f1_weighted', 
          'accuracy', 'balanced_accuracy']

for score in scores:
    print("# Tuning hyper-parameters for %s \n" % score)

    classifier = RandomizedSearchCV(
        SVC(), tuned_parameters, scoring='%s' % score
    ).fit(X_train, y_train)

    print("Best parameters set found on development set: \n")
    print(classifier.best_params_)
    print("\nGrid scores on development set:\n")
    
    means = classifier.cv_results_['mean_test_score']
    stds = classifier.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, classifier.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
    
    print("\nDetailed classification report:\n")
    y_pred = classifier.predict(X_test)
    print(classification_report(y_test, y_pred))
# Out:
# # Tuning hyper-parameters for precision_macro
#
# Best parameters set found on development set:
#
# {'C': 421.5007465348633, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
#
# Grid scores on development set:
#
# 0.985 (+/-0.013) for {'C': 421.5007465348633, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 0.984 (+/-0.016) for {'C': 909.1170749866291, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.972 (+/-0.017) for {'C': 10.0, 'kernel': 'linear'}
# 0.985 (+/-0.011) for {'C': 755.7224903007699, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.980 (+/-0.016) for {'C': 16.998952530523002, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.972 (+/-0.017) for {'C': 81.11308307896873, 'kernel': 'linear'}
# 0.985 (+/-0.018) for {'C': 339.59765422854696, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.972 (+/-0.017) for {'C': 284.8035868435802, 'kernel': 'linear'}
# 0.985 (+/-0.013) for {'C': 6.637405959585748, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.985 (+/-0.018) for {'C': 836.5475019539864, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        97
#            1       0.97      0.99      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.98      0.98      0.98        86
#            4       0.99      1.00      0.99        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.97      0.98        89
#            8       0.99      0.95      0.97        77
#            9       0.97      0.97      0.97        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
#
# # Tuning hyper-parameters for recall_micro
#
# Best parameters set found on development set:
#
# {'C': 961.0797942100619, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.970 (+/-0.019) for {'C': 12.32846739442066, 'kernel': 'linear'}
# 0.982 (+/-0.019) for {'C': 464.2239005327553, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 946.0399176711169, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.019) for {'C': 580.9493009380252, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.982 (+/-0.019) for {'C': 971.1351118616179, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.989 (+/-0.016) for {'C': 689.7005837187103, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.991 (+/-0.011) for {'C': 961.0797942100619, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.982 (+/-0.019) for {'C': 246.51708306911027, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.970 (+/-0.019) for {'C': 174.7528400007685, 'kernel': 'linear'}
# 0.982 (+/-0.015) for {'C': 1.3195162845476378, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       0.96      1.00      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.97      0.98        86
#            4       1.00      1.00      1.00        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.98      0.98        89
#            8       0.99      0.94      0.96        77
#            9       0.98      0.98      0.98        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
#
# # Tuning hyper-parameters for f1_weighted
#
# Best parameters set found on development set:
#
# {'C': 229.09975036054885, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.970 (+/-0.020) for {'C': 327.45491628777285, 'kernel': 'linear'}
# 0.970 (+/-0.020) for {'C': 7.564633275546289, 'kernel': 'linear'}
# 0.970 (+/-0.020) for {'C': 32.74549162877728, 'kernel': 'linear'}
# 0.970 (+/-0.020) for {'C': 1.321941148466029, 'kernel': 'linear'}
# 0.991 (+/-0.011) for {'C': 229.09975036054885, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.978 (+/-0.017) for {'C': 75.83170821044003, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 0.970 (+/-0.020) for {'C': 1.2328467394420661, 'kernel': 'linear'}
# 0.970 (+/-0.020) for {'C': 376.49358067924675, 'kernel': 'linear'}
# 0.970 (+/-0.020) for {'C': 1000.0, 'kernel': 'linear'}
# 0.982 (+/-0.020) for {'C': 316.17608102192236, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       0.96      1.00      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.97      0.98        86
#            4       1.00      1.00      1.00        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.98      0.98        89
#            8       0.99      0.94      0.96        77
#            9       0.98      0.98      0.98        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
#
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'C': 549.0799529784435, 'gamma': 'scale', 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.978 (+/-0.017) for {'C': 216.52497761867178, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.970 (+/-0.019) for {'C': 8.697490026177835, 'kernel': 'linear'}
# 0.983 (+/-0.020) for {'C': 2.947567634757809, 'degree': 2, 'gamma': 'auto', 'kernel': 'poly'}
# 0.983 (+/-0.020) for {'C': 638.7972911718479, 'degree': 2, 'gamma': 'scale', 'kernel': 'poly'}
# 0.991 (+/-0.011) for {'C': 549.0799529784435, 'gamma': 'scale', 'kernel': 'rbf'}
# 0.970 (+/-0.019) for {'C': 657.9332246575682, 'kernel': 'linear'}
# 0.973 (+/-0.018) for {'C': 30.73016220700933, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.970 (+/-0.019) for {'C': 100.0, 'kernel': 'linear'}
# 0.982 (+/-0.019) for {'C': 675.4263178379787, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.970 (+/-0.019) for {'C': 3.0538555088334154, 'kernel': 'linear'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        97
#            1       0.96      1.00      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.97      0.98        86
#            4       1.00      1.00      1.00        97
#            5       0.95      0.99      0.97        85
#            6       0.99      0.99      0.99        94
#            7       0.99      0.98      0.98        89
#            8       0.99      0.94      0.96        77
#            9       0.98      0.98      0.98        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
#
# # Tuning hyper-parameters for balanced_accuracy
#
# Best parameters set found on development set:
#
# {'C': 34.89131858117551, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
#
# Grid scores on development set:
#
# 0.971 (+/-0.017) for {'C': 11.497569953977356, 'kernel': 'linear'}
# 0.979 (+/-0.017) for {'C': 1.2722408731342092, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.971 (+/-0.017) for {'C': 3.2745491628777286, 'kernel': 'linear'}
# 0.984 (+/-0.011) for {'C': 34.89131858117551, 'degree': 4, 'gamma': 'auto', 'kernel': 'poly'}
# 0.974 (+/-0.017) for {'C': 6.0404108956048015, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
# 0.979 (+/-0.017) for {'C': 188.9290294207962, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 0.971 (+/-0.017) for {'C': 572.236765935022, 'kernel': 'linear'}
# 0.984 (+/-0.015) for {'C': 470.25813713427567, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 0.971 (+/-0.017) for {'C': 7.564633275546289, 'kernel': 'linear'}
# 0.974 (+/-0.017) for {'C': 33.84837682402082, 'degree': 6, 'gamma': 'scale', 'kernel': 'poly'}
#
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        97
#            1       0.97      0.99      0.98        89
#            2       1.00      1.00      1.00        92
#            3       0.99      0.98      0.98        86
#            4       0.99      0.99      0.99        97
#            5       0.97      0.99      0.98        85
#            6       0.99      1.00      0.99        94
#            7       0.98      0.97      0.97        89
#            8       0.97      0.95      0.96        77
#            9       0.97      0.97      0.97        93
#
#     accuracy                           0.98       899
#    macro avg       0.98      0.98      0.98       899
# weighted avg       0.98      0.98      0.98       899
